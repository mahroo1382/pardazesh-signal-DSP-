# %% [markdown]
# ## فصل 5 - آزمون 1
#
#
#  ## 1. ( qution )= نمونه برداری شده است  t=1/3000  با تناوب  x  , t=cos(200pit) سیگنال
#
#   * a.  را بدست آورید x[n] دنباله گسسته در زمان
#
#  solution=
#
# 𝑥[𝑛] = 𝑥𝑐(𝑛𝑇) = cos (2000𝜋 (n/3000)= cos 2pin/3
#
# * b. فرکانس نمونهبرداری برحسب رادیان بر ثانیه به دست آورید؟
#
# solution=
#
# Ω𝑆 = 2pi/T = ((2pi)/)1/3000=6000pi(rad/s)
#
#  * c. طیف سیگنال را به دست آورید؟
#
# solution=
#
# X(f) = π[δ(w − 2000π) + δ(w + 2000π] = 1/2 [δ(f − 1000) + δ(f + 1000]

# %% [markdown]
# ## 2. سیگنال های خروج در هر قسمت را رسم کنید . نمونه برداری شده است T با تناوب  X(t)  سیگنال پیوسته در زمان
#
# ![image.png](attachment:efddac24-de2b-4d00-b0b5-190ada6700ae.png)
#
#   را رسم می کنیم  x [n] ابتدا سیگنال نمونه برداری شده
#
#   ![image.png](attachment:737b1a80-5c8e-488c-86dc-fdabe0a79153.png)
#
#   دیدیم که از فیلتر ایده آل پایین گذر میتوان برای بازسازی سیگنال اصلی زمان پیوسته اولیه از روی نمونههای آن استفاده کرد. بنابراین بهمنظور بازسازی مجدد، سیگنال گسسته در زمان x[n] را به یک فیلتر پایین گذر ایده آل اعمال میکنیم. توجه داریم که فرکانس قطع سیگنال را همان فرکانس نمونهبرداری در نظر میگیریم خروجی فیلتر بهصورت زیر خواهد بود.
#
# ![image.png](attachment:8dd151e0-782e-451e-94c1-bf7405601760.png)
#
# درنهایت از اتصال لبه های به دست آمده در خروجی، سیگنال پیوسته در زمان 𝑥𝑟(𝑡) بازسازی میگردد.
#
# ![image.png](attachment:d279b942-edd7-41ff-8c66-8e0c11f35a88.png)

# %% [markdown]
# ## 3.  شکل زیر را در نظر بگیرید
#
# ![image.png](attachment:bd3c68fa-3aa5-4f77-b8ff-68c0bfb587e3.png)
#
#  * a. با توجه به شکل ابتدا توضیح دهید که چه فرایندی صورت گرفته است؟
#
# در تصویر بالا نمایی از نحوه نمونه برداری از یک سیگنال پیوسته در زمان توسط دنباله ضربه را میتوان مشاهده کرد. به طوری که برای نمونه برداری از سیگنال ورودی 𝑥(𝑡)، این سیگنال در قطار ضربه δ(t) با تناوب 𝑇𝑠 ضرب شده است. خروجی ضربکننده یک سیگنال گسسته در زمان است که سیگنال نمونه برداری شده نام دارد که آن را با 𝑦(𝑡) نشان داده است.
#
# * b.  را بدست اورده و رسم کنید y(t)  سپس خروجی
#
# ![image.png](attachment:f554b39b-12e1-40f7-818d-1b5a41a0963c.png)
